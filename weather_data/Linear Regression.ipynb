# %%
from scipy.stats import linregress 
import matplotlib.pyplot as plt

# %%
temps = [18.2,29.5,35.9,50.1,58.6,69.9,82.1,85.5,73.5,55.2,40.3,30.1]
daylight = [7.5,9.2,12.2,13.4,13.9,14.2,13.5,11.8,10.9,9.9,8.4,7.8]

# %%
plt.scatter(daylight,temps)
plt.xlabel("Hours of Daylight")
plt.ylabel("Average Monthly Temperature")
plt.show()

# %%
linregress(daylight,temps)

#rvalue = the correlation coeffect
# Out:
# LinregressResult(slope=6.142738828725954, intercept=-15.52012021432786, rvalue=0.6817926412381843, pvalue=0.01460422997141068, stderr=2.0842560684215923, intercept_stderr=23.56415642068499)

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(daylight,temps)

# %%
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 6.14x + -15.52

# %%
regress_values = [(day * slope + intercept) for day in daylight]

# %%
plt.scatter(daylight, temps)
plt.plot(daylight,regress_values)
plt.xlabel("Hours of Daylight")
plt.ylabel("Average Monthly Temperature")
plt.show()

# %%
# See the random_numbers File for more notes on Linear REgression
