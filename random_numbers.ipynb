# %%
import random as ra

# %% [markdown]
# # Generate Random Latitudes and Logitudes

# %% [markdown]
# ## The random() Function

# %%
ra.random()
# Any randomy number
# Out:
# 0.08227958985726624

# %%
x = 1
# Sets x to 1

latitudes = []
# Creates an empty list 

while x < 11:
    random_lat = ra.randint(-90, 89) + ra.random()
    latitudes.append(random_lat)
    x += 1
# The loop above says that between 1-11 (because x will start at 1, then loop through it in the while loop until the condition is met)
# Because the while loop condition is x<11, it says "while x is less than 11, loop through this"
# The random_lat value is created through calculating a random integer between -90 and 89 and add an other random number of any value 
# Whatever value is made in the random_lat calculation is added to the empty latitudes list after it is created 
# Then the loop says to add one to x before continuing to loop (if we took this out, it would keep going)
# The loop would keep going because x doesn't have a stopping point.  The loop would forever be met because x = 1 and that isn't changing

# %% [markdown]
# In the code block above, we:
#
#     Assign the variable x to 1.
#     Initialize an empty list, latitudes.
#     We create a while loop where we generate a random latitude and add it to the list.
#     After the random latitude is added to the list we add one to the variable "x".
#     The while loop condition is checked again and will continue to run as long as x is less than 11.

# %% [markdown]
# ## The randint() Function

# %%
ra.randint(-10,10)
# Gives you a random number, but a specitve value, 
# Will not give decimals
# Out:
# -9

# %% [markdown]
# ## The randrange() Function

# %%
ra.randrange(-9,9,2)
# Takes steps from the lower boundry to the upper boundyl then selects randomly from that 
# this is beuatiful for sequencing 
# the step will generate increments of a given integer value from teh lower to the upper limit 
# defaults to 1 if you don't have it 

x = 1
# Sets x to 1

latitudes_2 = []
# Creates an empty list 

while x < 11:
    random_lat_2 = ra.randrange(-90, 89, 2)
    latitudes_2.append(random_lat_2)
    x += 1
    
latitudes_2
# Out:
# [-24, -40, -16, -42, -88, 6, -88, -38, 24, -34]

# %% [markdown]
# ## The uniform() Function

# %%
ra.uniform(-10,10)
# Any random value, including decimal places after it.
# Out:
# -9.896154741955378

# %% [markdown]
# ## The NumPy and random Modules
# One way to generate more than a thousand latitudes and longitudes is to chain the NumPy module to the random module to create an array of latitudes or longitudes between the lowest and highest values, or –90° and 90°, and –180° and 180°, respectively. To accomplish this, we'll use the uniform() function from the random module.|
#
# **NOTE:** The NumPy module has a built-in random module, and supplements the built-in Python random module. There is no need to import the random module if we import the NumPy module, as it's redundant.

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.00, 90.00)
# This is the built in random function
# If you want to use the random package, you can shorten it to ra, but you can't in this funciton because 
# the function itself in the package is set to random
# Out:
# -6.316135722721086

# %%
# Below is the same things as above 
np.random.uniform(low = -90, high = 90)
# Out:
# 67.12647368259672

# %%
# use teh size parameter to get more than one floating point decimal number between any set values 
np.random.uniform(-90.000, 90.000, size = 50)
# This creates 50 values between the lower and upper bounds set here 

# We can use this for the lat and long generation if we wanted to, but we don't know if it is faster than using a loop 

# I think that the loop will be slower
# Out:
# array([ 51.87810709,  -0.62105108, -57.27945222, -52.10626325,
#        -56.62308614, -57.60192495, -76.87680988,  67.47776656,
#        -85.10493217, -16.67930146,  22.00452928,  33.72922361,
#        -73.79501236, -13.39804144, -14.51892337,  20.31701768,
#        -83.22269972,  14.16329136,  11.78861008,  25.18325654,
#         -0.40379523,  44.32456773, -64.00859725,  53.855896  ,
#         58.63256372, -54.94583266,  52.91788525, -11.95748321,
#        -57.6878186 , -70.5291652 , -33.40889908, -58.78379793,
#        -12.54946549,  82.73881989, -54.25828014, -74.28885641,
#         15.04153692,  23.92421842,  28.98131066, -16.40153499,
#         71.62484675,  52.46624061,  15.15749646,  42.61005851,
#        -88.51509383, -42.31129287,  24.98409246, -38.29531352,
#        -26.41528091, -54.27983832])

# %% [markdown]
# Timing Code

# %%
# Import timeit.
import timeit

# The timeit function takes a while to output, be patient!

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 13.1 µs ± 79.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = ra.randint(-90, 90) + ra.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)

# The loop does take longer
# It may not appear that way in the beginning, because the values at face look the opposite 
# The unit they are measured in matter 
# The mu seconds = microseconds 
# the ms = milisecons 

# microseconds are smaller than miliseconds
# Out:
# 1.54 ms ± 148 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Code Drill: Refactor code for the while loop so that it will generate teh 1,500 latitudes
latitudes(1500)
# We can just do this because the "def latitudes(size):" in the above chunk creates a function
# Out:
# [-44.38774658060299,
#  81.87884840327484,
#  -6.800081129160142,
#  -89.35823797805048,
#  -75.38874945581804,
#  59.22848756571307,
#  -7.705291634146034,
#  24.572477212916912,
#  -87.65700138447154,
#  83.32973620275159,
#  -28.40764213435045,
#  27.052065602960525,
#  -9.276238353576728,
#  -14.422550016171504,
#  -15.235718114828131,
#  -72.40550304443383,
#  8.295602857737634,
#  -45.05779585798506,
#  -53.95230465860178,
#  -23.106319076949568,
#  5.1451821649086344,
#  18.408602953912993,
#  -88.87498243681974,
#  52.02095400355311,
#  -41.82155626972015,
#  -67.01387621154056,
#  40.71753519597808,
#  -45.06157656060786,
#  -33.59710395455981,
#  87.341168369924,
#  48.348622670517344,
#  90.6307700654309,
#  24.835240742778847,
#  18.874526385462932,
#  -17.043831846400916,
#  46.73749739080487,
#  -81.67061390224265,
#  33.636339136542816,
#  -63.38680801958848,
#  -28.389552514534568,
#  36.36714748587723,
#  80.70841892718742,
#  -52.88048719572297,
#  -31.26895227097163,
#  9.43997063653656,
#  -4.52965046402226,
#  38.21057438511527,
#  -67.46057893664072,
#  -26.957018746665344,
#  -54.36995614729451,
#  -69.88792349902927,
#  78.71995151339692,
#  -8.639140127689839,
#  -55.912645481349074,
#  -15.683626612373658,
#  65.97032555540572,
#  -15.1838893411896,
#  -23.76104660423338,
#  49.831792069396734,
#  47.16565317214961,
#  -11.593588444407573,
#  -82.10435663882858,
#  63.825799454142526,
#  24.195723402083,
#  -89.6110829327802,
#  68.50471504176262,
#  13.728493158384433,
#  60.74287121067665,
#  -58.44408880006299,
#  31.28975832380363,
#  -5.74151697200767,
#  37.11682230288294,
#  28.45186458715811,
#  77.92083051300018,
#  6.171770255550149,
#  34.4578475693482,
#  34.427640194829166,
#  7.286244368243217,
#  -71.66456063812818,
#  -1.1079144295650274,
#  55.97716157675063,
#  -47.98643080227278,
#  55.49102098354045,
#  -25.128834551705935,
#  -21.543632334050166,
